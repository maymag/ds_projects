# %% [markdown]
# # COVID-19 OPEN RESEARCH DATASET

# %%
import os
import json
import pandas as pd

# %%
# %cd '/home/myilmaz/devel/covid551982_1475446_bundle_archive/'
# Out:
# /home/myilmaz/devel/covid551982_1475446_bundle_archive

# %% [markdown]
# ## Papers  researching chronic kidney disease as a comorbidity risk

# %%
kags=pd.DataFrame(None)
for i in os.listdir('Kaggle/target_tables/8_risk_factors/'):
    kag=pd.read_csv('Kaggle/target_tables/8_risk_factors/'+i)
    kags=kags.append(kag)

# %%
kags.head()
# Out:
#    Unnamed: 0        Date                                              Study  \
# 0           0  2020-06-01  Characteristics and Outcomes of COVID-19 Patie...
# 1           1  2020-05-22  Interim Analysis of Risk Factors for Severe Ou...
# 2           2  2020-05-22  Interim Analysis of Risk Factors for Severe Ou...
# 3           3  2020-05-07  OpenSAFELY: factors associated with COVID-19-r...
# 4           4  2020-04-25  The role of comorbidities and clinical predict...
#
#                                           Study Link  Journal   Severe  \
# 0  http://medrxiv.org/cgi/content/short/2020.05.2...  MedRxiv      NaN
# 1  http://medrxiv.org/cgi/content/short/2020.05.1...  MedRxiv  RR 1.29
# 2  http://medrxiv.org/cgi/content/short/2020.05.1...  MedRxiv  RR 1.39
# 3  http://medrxiv.org/cgi/content/short/2020.05.0...  MedRxiv      NaN
# 4         http://doi.org/10.1101/2020.04.21.20074633      NaN  OR 1.08
#
#    Severe lower bound  Severe upper bound Severe p-value Severe Significant  \
# 0                 NaN                 NaN            NaN                NaN
# 1                1.13                1.47            NaN        Significant
# 2                1.22                1.58            NaN        Significant
# 3                 NaN                 NaN            NaN                NaN
# 4                0.18                6.26            NaN    Not Significant
#
#    ... Fatality Calculated                            Multivariate adjustment  \
# 0  ...          Calculated                                                NaN
# 1  ...           Extracted  age, sex, race/ethnicity, smoker, hypertension...
# 2  ...           Extracted                                                NaN
# 3  ...           Extracted  age, gender, obesity, smoking status, diabetes...
# 4  ...                 NaN                                                NaN
#
#                             Study Type  Sample Size  \
# 0    Retrospective observational study        13442
# 1    Retrospective observational study         2490
# 2    Retrospective observational study         2490
# 3    Retrospective observational study   17,425,445
# 4  Systematic review and meta-analysis    3 studies
#
#                                     Study Population  Added on Critical only  \
# 0  New York City Health and Hospital between Marc...       NaN             N
# 1  124 counties located in 14 states 113 (Califor...       NaN             Y
# 2  123 counties located in 14 states 113 (Califor...       NaN             Y
# 3  TPP general practice in England from February ...       NaN             N
# 4  PubMed, Scopus, EMBASE, Web of Science, and Go...  5/6/2020             Y
#
#   Discharged vs. death? Critical only? Discharge vs. death?
# 0                     N            NaN                  NaN
# 1                     N            NaN                  NaN
# 2                     N            NaN                  NaN
# 3                     N            NaN                  NaN
# 4                     N            NaN                  NaN
#
# [5 rows x 28 columns]

# %%
# %ls document_parses
# Out:
# comorbidity2.ipynb  covid.ipynb             covidModel.ipynb
# comorbidity.ipynb   covidModel-2.ipynb      pdf_json/
# covid-Copy1.ipynb   covidModel-Copy2.ipynb  pmc_json/

# %%
keep=['Epidemiology, clinical course, and outcomes of critically ill adults with COVID-19 in New York City: a prospective cohort study','Psychiatric Predictors of COVID-19 Outcomes in a Skilled Nursing Facility Cohort','COVID-19 in Iran, a comprehensive investigation from exposure to treatment outcomes']
arts=set(kags['Study'])-set(keep)

# %%
os.path.getsize('document_parses/pdf_json')/1000000
# Out:
# 8.634368

# %%
docs=[]
alltext=[]
for i in os.listdir('document_parses/pdf_json'):
    save=0
    savee=0

    with open('document_parses/pdf_json/'+i) as json_file:
        data = json.load(json_file)
        if data['metadata']['title'] in list(arts):
            #print(data['metadata']['title'])
            doc=[]
            text=''
            for c,j in enumerate(data['body_text']):
            
          
                row=[i,data['metadata']['title'],data['body_text'][c]['section'],c,data['body_text'][c]['text']]

                doc.append(row)
                text+=data['body_text'][c]['text']
            
            if doc not in docs:
                docs.append(doc)
                alltext.append(text)
        else:
            pass

# %%
jsons=[j[0] for i in docs for j in i]
titles=[j[1] for i in docs for j in i]
sections=[j[2] for i in docs for j in i]
sectionNo=[j[3] for i in docs for j in i]
text=[j[4] for i in docs for j in i]
risks=pd.DataFrame(None,columns=['jsons','titles','sections','sectionNo','text'])

# %%
risks=pd.DataFrame(None,columns=['jsons','titles','sections','sectionNo','text'])
risks.jsons=jsons
risks.titles=titles
risks.sections=sections
risks.sectionNo=sectionNo
risks.text=text

# %%
risks.head()
# Out:
#                                            jsons  \
# 0  5111c718f426624c7bcb8f11d7137177f6e85bf3.json
# 1  5111c718f426624c7bcb8f11d7137177f6e85bf3.json
# 2  5111c718f426624c7bcb8f11d7137177f6e85bf3.json
# 3  5111c718f426624c7bcb8f11d7137177f6e85bf3.json
# 4  5111c718f426624c7bcb8f11d7137177f6e85bf3.json
#
#                                               titles sections  sectionNo  \
# 0  When a nephrology ward becomes a COVID-19 ward...                   0
# 1  When a nephrology ward becomes a COVID-19 ward...                   1
# 2  When a nephrology ward becomes a COVID-19 ward...                   2
# 3  When a nephrology ward becomes a COVID-19 ward...                   3
# 4  When a nephrology ward becomes a COVID-19 ward...                   4
#
#                                                 text
# 0  Since that time, Lombardy has become the epice...
# 1  While patients with chronic kidney disease (CK...
# 2  On this background we would like to report on ...
# 3  Patients admitted to the Nephrology ward were ...
# 4  Complications were extremely frequent in this ...

# %%
docs=risks.copy(deep=True)
docs.drop_duplicates(keep='first',inplace=True)
# NUMBER OF UNIQUE DOCUMENTS IN THE DATA SET
docs['jsons'].nunique()
# Out:
# 98

# %%
docs.to_csv('comorbids.csv')
docs=pd.read_csv('comorbids.csv')

# %%
import numpy as np
np.min([len(i) for i in alltext])
np.max([len(i) for i in alltext])

print('Average document length is {} words'.format(np.mean([len(i) for i in alltext])))
# Out:
# Average document length is 16896.051020408162 words

# %% [markdown]
# ## Use pretrained NER model to find Problems, Tests, and Treatments

# %%
import os


import pyspark.sql.functions as F
from pyspark.sql.functions import monotonically_increasing_id
import json
import os
from pyspark.ml import Pipeline
from pyspark.sql import SparkSession


from sparknlp.annotator import *

from sparknlp.base import *

# Install pyspark
! pip install --ignore-installed -q pyspark==2.4.4


# Install Spark NLP
! pip install --ignore-installed -q spark-nlp==2.5


import sparknlp

print (sparknlp.version())

import json
import os
from pyspark.ml import Pipeline
from pyspark.sql import SparkSession
from sparknlp.annotator import *

from sparknlp.base import *

from pyspark.sql.functions import monotonically_increasing_id
import pyspark.sql.functions as F
import pyspark.sql.types as t
# Out:
# WARNING: You are using pip version 20.1; however, version 20.2.4 is available.
# You should consider upgrading via the '/home/myilmaz/devel/mag/notebooks/3.7env/bin/python -m pip install --upgrade pip' command.
# ERROR: spark-nlp-jsl 2.5.4rc4 has requirement spark-nlp==2.5.4, but you'll have spark-nlp 2.5.0 which is incompatible.
# WARNING: You are using pip version 20.1; however, version 20.2.4 is available.
# You should consider upgrading via the '/home/myilmaz/devel/mag/notebooks/3.7env/bin/python -m pip install --upgrade pip' command.
# 2.5.0

# %%
spark=sparknlp.start()

# %%
docs.fillna('',inplace=True)

# %%
docs.head(1)
# Out:
#    Unnamed: 0                                          jsons  \
# 0           0  5111c718f426624c7bcb8f11d7137177f6e85bf3.json
#
#                                               titles sections  sectionNo  \
# 0  When a nephrology ward becomes a COVID-19 ward...                   0
#
#                                                 text
# 0  Since that time, Lombardy has become the epice...

# %%
docs['lenSection']=docs['text'].apply(lambda x: len(x))

# %%
sparkdocs=spark.createDataFrame(docs).toDF('index','docid','title','section','sectionNo','text','lenSection')

# %%
document_assembler = DocumentAssembler() \
        .setInputCol("text")\
        .setOutputCol('document')
    
sentence_detector = SentenceDetector() \
        .setInputCols(["document"]) \
        .setOutputCol("sentence")

tokenizer = Tokenizer() \
        .setInputCols(["sentence"]) \
        .setOutputCol("token")

word_embeddings = WordEmbeddingsModel.load("/home/myilmaz/cache_pretrained/embeddings_clinical_en_2.4.0_2.4_1580237286004")\
  .setInputCols(["sentence", "token"])\
  .setOutputCol("embeddings")
embeddingsSentence = SentenceEmbeddings() \
      .setInputCols(["sentence", "embeddings"]) \
      .setOutputCol("sent_embeddings") \
      .setPoolingStrategy("AVERAGE")
clinical_ner = NerDLModel.load('/home/myilmaz/cache_pretrained/ner_clinical_en_2.4.0_2.4_1580237286004') \
        .setInputCols(["sentence", "token", "embeddings"]) \
        .setOutputCol("ner")
ner_converter = NerConverter() \
  .setInputCols(["sentence", "token", "ner"]) \
  .setOutputCol("ner_chunk")
nlpPipeline = Pipeline(stages=[document_assembler,sentence_detector,tokenizer,
    word_embeddings,embeddingsSentence,
    clinical_ner,ner_converter
    ])


empty_data = spark.createDataFrame([[""]]).toDF("text")

model = nlpPipeline.fit(empty_data)

# %%
results=model.transform(sparkdocs)

# %%
embeds = results.select('docid','section','sectionNo','lenSection',F.explode(F.arrays_zip('sent_embeddings.metadata','sent_embeddings.embeddings')).alias("cols")) \
        .select('docid','section','sectionNo','lenSection',F.expr("cols['0'].sentence").alias("sentid"),
        F.col('cols.1').alias("sent_embeddings"))

# %%
embeds.show(100)
# Out:
# +--------------------+--------------------+---------+----------+------+--------------------+
# |               docid|             section|sectionNo|lenSection|sentid|     sent_embeddings|
# +--------------------+--------------------+---------+----------+------+--------------------+
# |5111c718f426624c7...|                    |        0|       763|     0|[0.07153898, -0.2...|
# |5111c718f426624c7...|                    |        0|       763|     1|[0.07153898, -0.2...|
# |5111c718f426624c7...|                    |        0|       763|     2|[0.07153898, -0.2...|
# |5111c718f426624c7...|                    |        0|       763|     3|[0.07153898, -0.2...|
# |5111c718f426624c7...|                    |        0|       763|     4|[0.07153898, -0.2...|
# |5111c718f426624c7...|                    |        0|       763|     5|[0.07153898, -0.2...|
# |5111c718f426624c7...|                    |        1|       274|     0|[0.06047398, -0.1...|
# |5111c718f426624c7...|                    |        2|       996|     0|[0.020759622, -0....|
# |5111c718f426624c7...|                    |        2|       996|     1|[0.020759622, -0....|
# |5111c718f426624c7...|                    |        2|       996|     2|[0.020759622, -0....|
# |5111c718f426624c7...|                    |        2|       996|     3|[0.020759622, -0....|
# |5111c718f426624c7...|                    |        2|       996|     4|[0.020759622, -0....|
# |5111c718f426624c7...|                    |        3|       908|     0|[0.080077656, -0....|
# |5111c718f426624c7...|                    |        3|       908|     1|[0.080077656, -0....|
# |5111c718f426624c7...|                    |        3|       908|     2|[0.080077656, -0....|
# |5111c718f426624c7...|                    |        3|       908|     3|[0.080077656, -0....|
# |5111c718f426624c7...|                    |        3|       908|     4|[0.080077656, -0....|
# |5111c718f426624c7...|                    |        3|       908|     5|[0.080077656, -0....|
# |5111c718f426624c7...|                    |        3|       908|     6|[0.080077656, -0....|
# |5111c718f426624c7...|                    |        3|       908|     7|[0.080077656, -0....|
# |5111c718f426624c7...|                    |        4|       827|     0|[0.047014873, -0....|
# |5111c718f426624c7...|                    |        4|       827|     1|[0.047014873, -0....|
# |5111c718f426624c7...|                    |        4|       827|     2|[0.047014873, -0....|
# |5111c718f426624c7...|                    |        4|       827|     3|[0.047014873, -0....|
# |5111c718f426624c7...|                    |        5|      1533|     0|[0.021406865, -0....|
# |5111c718f426624c7...|                    |        5|      1533|     1|[0.021406865, -0....|
# |5111c718f426624c7...|                    |        5|      1533|     2|[0.021406865, -0....|
# |5111c718f426624c7...|                    |        5|      1533|     3|[0.021406865, -0....|
# |5111c718f426624c7...|                    |        5|      1533|     4|[0.021406865, -0....|
# |5111c718f426624c7...|                    |        5|      1533|     5|[0.021406865, -0....|
# |5111c718f426624c7...|                    |        5|      1533|     6|[0.021406865, -0....|
# |5111c718f426624c7...|                    |        5|      1533|     7|[0.021406865, -0....|
# |5111c718f426624c7...|                    |        5|      1533|     8|[0.021406865, -0....|
# |5111c718f426624c7...|                    |        5|      1533|     9|[0.021406865, -0....|
# |5111c718f426624c7...|                    |        6|      3689|     0|[0.040954802, -0....|
# |5111c718f426624c7...|                    |        6|      3689|     1|[0.040954802, -0....|
# |5111c718f426624c7...|                    |        6|      3689|     2|[0.040954802, -0....|
# |5111c718f426624c7...|                    |        6|      3689|     3|[0.040954802, -0....|
# |5111c718f426624c7...|                    |        6|      3689|     4|[0.040954802, -0....|
# |5111c718f426624c7...|                    |        6|      3689|     5|[0.040954802, -0....|
# |5111c718f426624c7...|                    |        6|      3689|     6|[0.040954802, -0....|
# |5111c718f426624c7...|                    |        6|      3689|     7|[0.040954802, -0....|
# |5111c718f426624c7...|                    |        6|      3689|     8|[0.040954802, -0....|
# |5111c718f426624c7...|                    |        6|      3689|     9|[0.040954802, -0....|
# |5111c718f426624c7...|                    |        6|      3689|    10|[0.040954802, -0....|
# |5111c718f426624c7...|                    |        6|      3689|    11|[0.040954802, -0....|
# |5111c718f426624c7...|                    |        6|      3689|    12|[0.040954802, -0....|
# |5111c718f426624c7...|                    |        6|      3689|    13|[0.040954802, -0....|
# |5111c718f426624c7...|                    |        6|      3689|    14|[0.040954802, -0....|
# |5111c718f426624c7...|                    |        6|      3689|    15|[0.040954802, -0....|
# |5111c718f426624c7...|                    |        6|      3689|    16|[0.040954802, -0....|
# |5111c718f426624c7...|                    |        7|      1045|     0|[0.06309712, -0.2...|
# |5111c718f426624c7...|                    |        7|      1045|     1|[0.06309712, -0.2...|
# |5111c718f426624c7...|                    |        7|      1045|     2|[0.06309712, -0.2...|
# |5111c718f426624c7...|                    |        8|       311|     0|[0.0144117465, -0...|
# |5111c718f426624c7...|                    |        9|       113|     0|[0.14777605, -0.2...|
# |5111c718f426624c7...|                    |       10|       381|     0|[0.14370497, -0.3...|
# |5111c718f426624c7...|                    |       10|       381|     1|[0.14370497, -0.3...|
# |5111c718f426624c7...|                    |       11|       776|     0|[0.12550946, -0.2...|
# |5111c718f426624c7...|                    |       11|       776|     1|[0.12550946, -0.2...|
# |5111c718f426624c7...|                    |       11|       776|     2|[0.12550946, -0.2...|
# |5111c718f426624c7...|                    |       11|       776|     3|[0.12550946, -0.2...|
# |5111c718f426624c7...|Compliance with e...|       12|        83|     0|[0.15888385, -0.2...|
# |5111c718f426624c7...|Compliance with e...|       13|       278|     0|[0.11219592, -0.2...|
# |5111c718f426624c7...|Compliance with e...|       14|        71|     0|[0.17383258, -0.2...|
# |c3cf02d2f1c97df0c...|          Background|        0|       706|     0|[0.13529949, -0.1...|
# |c3cf02d2f1c97df0c...|          Background|        0|       706|     1|[0.13529949, -0.1...|
# |c3cf02d2f1c97df0c...|          Background|        0|       706|     2|[0.13529949, -0.1...|
# |c3cf02d2f1c97df0c...|          Background|        0|       706|     3|[0.13529949, -0.1...|
# |c3cf02d2f1c97df0c...|          Background|        1|       846|     0|[0.10715095, -0.0...|
# |c3cf02d2f1c97df0c...|          Background|        1|       846|     1|[0.10715095, -0.0...|
# |c3cf02d2f1c97df0c...|          Background|        1|       846|     2|[0.10715095, -0.0...|
# |c3cf02d2f1c97df0c...|          Background|        1|       846|     3|[0.10715095, -0.0...|
# |c3cf02d2f1c97df0c...|          Background|        1|       846|     4|[0.10715095, -0.0...|
# |c3cf02d2f1c97df0c...|          Background|        1|       846|     5|[0.10715095, -0.0...|
# |c3cf02d2f1c97df0c...|          Background|        1|       846|     6|[0.10715095, -0.0...|
# |c3cf02d2f1c97df0c...|          Background|        2|       319|     0|[0.057463568, -0....|
# |c3cf02d2f1c97df0c...|          Background|        2|       319|     1|[0.057463568, -0....|
# |c3cf02d2f1c97df0c...|            Subjects|        3|      1094|     0|[-0.023908112, -0...|
# |c3cf02d2f1c97df0c...|            Subjects|        3|      1094|     1|[-0.023908112, -0...|
# |c3cf02d2f1c97df0c...|            Subjects|        3|      1094|     2|[-0.023908112, -0...|
# |c3cf02d2f1c97df0c...|            Subjects|        3|      1094|     3|[-0.023908112, -0...|
# |c3cf02d2f1c97df0c...|            Subjects|        3|      1094|     4|[-0.023908112, -0...|
# |c3cf02d2f1c97df0c...|            Subjects|        3|      1094|     5|[-0.023908112, -0...|
# |c3cf02d2f1c97df0c...|            Subjects|        3|      1094|     6|[-0.023908112, -0...|
# |c3cf02d2f1c97df0c...|            Subjects|        3|      1094|     7|[-0.023908112, -0...|
# |c3cf02d2f1c97df0c...|            Subjects|        3|      1094|     8|[-0.023908112, -0...|
# |c3cf02d2f1c97df0c...|            Subjects|        3|      1094|     9|[-0.023908112, -0...|
# |c3cf02d2f1c97df0c...|Baseline data and...|        4|       636|     0|[0.07159074, -0.3...|
# |c3cf02d2f1c97df0c...|Baseline data and...|        4|       636|     1|[0.07159074, -0.3...|
# |c3cf02d2f1c97df0c...|Baseline data and...|        4|       636|     2|[0.07159074, -0.3...|
# |c3cf02d2f1c97df0c...|Baseline data and...|        4|       636|     3|[0.07159074, -0.3...|
# |c3cf02d2f1c97df0c...|Baseline data and...|        4|       636|     4|[0.07159074, -0.3...|
# |c3cf02d2f1c97df0c...|Baseline data and...|        4|       636|     5|[0.07159074, -0.3...|
# |c3cf02d2f1c97df0c...|Statistical analysis|        5|      1038|     0|[0.048227284, -0....|
# |c3cf02d2f1c97df0c...|Statistical analysis|        5|      1038|     1|[0.048227284, -0....|
# |c3cf02d2f1c97df0c...|Statistical analysis|        5|      1038|     2|[0.048227284, -0....|
# |c3cf02d2f1c97df0c...|Statistical analysis|        5|      1038|     3|[0.048227284, -0....|
# |c3cf02d2f1c97df0c...|Statistical analysis|        5|      1038|     4|[0.048227284, -0....|
# |c3cf02d2f1c97df0c...|Statistical analysis|        5|      1038|     5|[0.048227284, -0....|
# +--------------------+--------------------+---------+----------+------+--------------------+
# only showing top 100 rows

# %%
exploded = results.select('docid','title','section','sectionNo','lenSection',F.explode(F.arrays_zip('token.metadata','token.result','token.begin','ner.result')).alias("cols")) \
        .select('docid','title','section','sectionNo','lenSection',F.expr("cols['0'].sentence").alias("sentid"),
        F.col('cols.1').alias("token"),F.col('cols.2').alias('tokenStart'),F.col('cols.3').alias("label"))

# %%
from pyspark.sql.functions import udf, col

join1=udf(lambda x:','.join(x))
stringify = udf(lambda x: [str(j) for j in x])
embeds=embeds.withColumn("sent_embeddings", stringify(col("sent_embeddings")))
embeds=embeds.withColumn("sent_embeddings", join1(col("sent_embeddings")))

# %%
exploded.show()
# Out:
# +--------------------+--------------------+-------+---------+----------+------+-------------+----------+-----+
# |               docid|               title|section|sectionNo|lenSection|sentid|        token|tokenStart|label|
# +--------------------+--------------------+-------+---------+----------+------+-------------+----------+-----+
# |5111c718f426624c7...|When a nephrology...|       |        0|       763|     0|        Since|         0|    O|
# |5111c718f426624c7...|When a nephrology...|       |        0|       763|     0|         that|         6|    O|
# |5111c718f426624c7...|When a nephrology...|       |        0|       763|     0|         time|        11|    O|
# |5111c718f426624c7...|When a nephrology...|       |        0|       763|     0|            ,|        15|    O|
# |5111c718f426624c7...|When a nephrology...|       |        0|       763|     0|     Lombardy|        17|    O|
# |5111c718f426624c7...|When a nephrology...|       |        0|       763|     0|          has|        26|    O|
# |5111c718f426624c7...|When a nephrology...|       |        0|       763|     0|       become|        30|    O|
# |5111c718f426624c7...|When a nephrology...|       |        0|       763|     0|          the|        37|    O|
# |5111c718f426624c7...|When a nephrology...|       |        0|       763|     0|    epicentre|        41|    O|
# |5111c718f426624c7...|When a nephrology...|       |        0|       763|     0|           of|        51|    O|
# |5111c718f426624c7...|When a nephrology...|       |        0|       763|     0|     COVID-19|        54|    O|
# |5111c718f426624c7...|When a nephrology...|       |        0|       763|     0|           in|        63|    O|
# |5111c718f426624c7...|When a nephrology...|       |        0|       763|     0|        Italy|        66|    O|
# |5111c718f426624c7...|When a nephrology...|       |        0|       763|     0|            ,|        71|    O|
# |5111c718f426624c7...|When a nephrology...|       |        0|       763|     0|         with|        73|    O|
# |5111c718f426624c7...|When a nephrology...|       |        0|       763|     0|approximately|        78|    O|
# |5111c718f426624c7...|When a nephrology...|       |        0|       763|     0|          38%|        92|    O|
# |5111c718f426624c7...|When a nephrology...|       |        0|       763|     0|           of|        96|    O|
# |5111c718f426624c7...|When a nephrology...|       |        0|       763|     0|          the|        99|    O|
# |5111c718f426624c7...|When a nephrology...|       |        0|       763|     0|      165,155|       103|    O|
# +--------------------+--------------------+-------+---------+----------+------+-------------+----------+-----+
# only showing top 20 rows

# %% [markdown]
# ## Save annotated documents for further analysis

# %%
exploded.write.option("header", "true").csv("comorbids2.csv")

# %% [markdown]
# embeds.write.option("header", "true").csv("embeddings.csv")

# %%
exploded.columns
# Out:
# ['docid',
#  'title',
#  'section',
#  'sectionNo',
#  'lenSection',
#  'sentid',
#  'token',
#  'tokenStart',
#  'label']

# %%
os.listdir('comorbids2.csv')[0]
# Out:
# '.part-00003-c79270b5-5b73-4da5-a889-fa9ead5fa7ba-c000.csv.crc'

# %%
import pyspark.sql.types as t
myschema = t.StructType(
   [
    t.StructField('docid', t.StringType(), True),
    t.StructField('title', t.StringType(), True),
    t.StructField('section', t.StringType(), True),
    t.StructField('sectionNo', t.StringType(), True),
    t.StructField('lenSection', t.IntegerType(), True),
    t.StructField('sentid', t.StringType(), True),
    t.StructField('token', t.StringType(), True),
    t.StructField('tokenStart', t.StringType(), True),
    t.StructField('label', t.StringType(), True)

   ]
  )

# %% [markdown]
# import pyspark.sql.types as t
# myschema2 = t.StructType(
#    [
#     t.StructField('docid', t.StringType(), True),
#     t.StructField('section', t.StringType(), True),
#     t.StructField('sectionNo', t.StringType(), True),
#     t.StructField('sentid', t.StringType(), True),
#     t.StructField('sent_embeddings', t.StringType(), True)
#    ]
#   )

# %%
csvs=os.listdir('comorbids2.csv')
big=pd.DataFrame(None)
for i in csvs:
    
    dfs=spark.read.csv('comorbids2.csv/'+i,sep=',',schema=myschema,header=True)
    one=dfs.toPandas()
    big=big.append(one)

# %% [markdown]
# csvs=os.listdir('embeddings.csv')
# embed=pd.DataFrame(None)
# for i in csvs:
#
#     dfs=spark.read.csv('embeddings.csv/'+i,sep=',',schema=myschema2,header=True)
#     one=dfs.toPandas()
#     embed=embed.append(one)

# %%
import numpy as np

tokens=[]
savei=''
save=0
for i,j in zip(big.token,big.label):
    if j.split('-')[0]!='I':
        if save<0:
            tokens[save]=savei
            tokens.append(None)
            savei=i
            save=0
            continue
        else:
            tokens.append(savei)
            savei=i
            save=0
            continue
    elif j.split('-')[0]=='I':
        savei+=' '+i
        save-=1
        tokens.append(None)
    else:
        tokens.append(None)

               
if save<0:
    tokens[save]=savei
    tokens.append(None)
else:
    tokens.append(savei) 
    
tokens=tokens[1:]

# %%
big['chunks']=tokens

# %%
big=big.drop_duplicates().reset_index(drop=True)

# %%
big.to_csv('allrisks.csv',index=False)

# %%
testdf=big[big['chunks'].notnull()]
testdf=testdf[testdf['label']!='O']
testdf['chunks'].value_counts()

# %%
#Make chunk embeddings

# %%
document = DocumentAssembler().setInputCol("chunks").setOutputCol("sentence1")
token = Tokenizer().setInputCols(['sentence1']).setOutputCol('token_init1')
normalizer = Normalizer() \
    .setInputCols(["token_init1"]) \
    .setOutputCol("token1") \
    .setLowercase(True)
word_embeddings = WordEmbeddingsModel.load("/home/myilmaz/cache_pretrained/embeddings_clinical_en_2.4.0_2.4_1580237286004")\
  .setInputCols(["sentence1","token1"])\
  .setOutputCol("embeddings1")
embeddingsSentence = SentenceEmbeddings() \
      .setInputCols(["sentence1", "embeddings1"]) \
      .setOutputCol("chunk_embeddings1") \
      .setPoolingStrategy("AVERAGE")

pipeline = Pipeline(
    stages = [
        document,
        token,
        normalizer,
        word_embeddings,
        embeddingsSentence
    ]
)
model = pipeline.fit(spark.createDataFrame([[""]]).toDF("chunks"))

# %%
sparkdf=spark.createDataFrame(testdf[['chunks']].reset_index())

# %%
modeldf=model.transform(sparkdf).select('index','chunk_embeddings1.embeddings').toPandas()

# %%
test=testdf.reset_index().merge(modeldf,on='index',how='left')

# %%
## prepare sentence based features

# %%
bigdf=big.fillna('O')

# %%
allrisks=bigdf.merge(test,on=list(set(bigdf.columns)-{'title'}),how='left')
allrisks=allrisks.drop(columns=['title_y'])

# %%
allrisks['embeddings'].fillna(0,inplace=True)

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
bigdf['study']=bigdf['chunks'].apply(lambda x: str(x).lower().find('study')>=0)
bigdf['studies']=bigdf['chunks'].apply(lambda x: str(x).lower().find('studies')>=0)
bigdf['meta']=bigdf['chunks'].apply(lambda x: str(x).lower().find('meta-analysis')>=0)
bigdf['data']=bigdf['chunks'].apply(lambda x: str(x).lower().find('data analysis')>=0 )
bigdf['stats']=bigdf['chunks'].apply(lambda x:str(x).lower().find('statistical analysis')>=0 )
bigdf['review']=bigdf['chunks'].apply(lambda x: str(x).lower().find('a systematic review')>=0 )
bigdf['review2']=bigdf['chunks'].apply(lambda x: str(x).lower().find('a systemic review')>=0 )
bigdf['predict']=bigdf['chunks'].apply(lambda x: str(x).lower().find('prediction')>=0 )
bigdf['data2']=bigdf['chunks'].apply(lambda x: str(x).lower()=='data')

# %%
bigdf['remove']=bigdf['study']+bigdf['studies']+bigdf['meta']+bigdf['data']+bigdf['stats']+bigdf['review']+bigdf['predict']+bigdf['review2']+bigdf['data2']
# Out:
# /home/myilmaz/devel/mag/notebooks/3.7env/lib/python3.7/site-packages/pandas/core/computation/expressions.py:178: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   f"evaluating in Python space because the {repr(op_str)} "

# %%
newlabel=[]
for i,j in zip(bigdf['remove'],bigdf['label']):
    if i==1:
        if j.split('-')[-1]=='TEST':
            newlabel.append('O')
        else:
            newlabel.append(j)
    else:
        newlabel.append(j)

# %%
bigdf2=bigdf.drop(columns=['study','studies','meta','data','stats','review','review2','predict','remove','data2'])

# %%
bigdf2['label']=newlabel

# %%
bigdf2['preexisting']=1

# %%
bigdf2.head()
# Out:
#                                            docid  \
# 0  687fec04ac33c91790ef56acf1f00d53f2b91d1d.json
# 1  687fec04ac33c91790ef56acf1f00d53f2b91d1d.json
# 2  687fec04ac33c91790ef56acf1f00d53f2b91d1d.json
# 3  687fec04ac33c91790ef56acf1f00d53f2b91d1d.json
# 4  687fec04ac33c91790ef56acf1f00d53f2b91d1d.json
#
#                                                                                               title  \
# 0  Age-adjusted associations between comorbidity and outcomes of COVID-19: a review of the evidence
# 1  Age-adjusted associations between comorbidity and outcomes of COVID-19: a review of the evidence
# 2  Age-adjusted associations between comorbidity and outcomes of COVID-19: a review of the evidence
# 3  Age-adjusted associations between comorbidity and outcomes of COVID-19: a review of the evidence
# 4  Age-adjusted associations between comorbidity and outcomes of COVID-19: a review of the evidence
#
#                       section sectionNo sentid         token tokenStart label  \
# 0  INCLUDE EXCLUDE Population         8      0  Non-COVID-19          0     O
# 1  INCLUDE EXCLUDE Population         8      0      patients         13     O
# 2  INCLUDE EXCLUDE Population         8      0             (         22     O
# 3  INCLUDE EXCLUDE Population         8      0           e.g         23     O
# 4  INCLUDE EXCLUDE Population         8      0             .         26     O
#
#          chunks  preexisting
# 0  Non-COVID-19            1
# 1      patients            1
# 2             (            1
# 3           e.g            1
# 4             .            1

# %%
chunks=[]
labels=[]
chunkStart=[]
for i,j,k in zip(bigdf2['chunks'],bigdf2['label'],bigdf2['tokenStart']):
    if (j=='O' or j.split('-')[0]=='I'):
        chunks.append(None)
        labels.append(None)
        chunkStart.append(None)
    else:
        if i!='O':
            chunks.append(i)
        else:
            chunks.append(None)
        labels.append(j)
        chunkStart.append(k)

# %%
bigdf2['label']=labels
bigdf2['chunks']=chunks
bigdf2['chunkStart']=chunkStart

# %%
bigdf2['tokenStart']=bigdf2['tokenStart'].apply(lambda x: [x])
bigdf2['token']=bigdf2['token'].apply(lambda x: [x])
bigdf2['label']=bigdf2['label'].apply(lambda x: [x])
bigdf2['chunks']=bigdf2['chunks'].apply(lambda x: [x])
bigdf2['chunkStart']=bigdf2['chunkStart'].apply(lambda x: [x])

# %%
bigdf2.head()
# Out:
#                                            docid  \
# 0  687fec04ac33c91790ef56acf1f00d53f2b91d1d.json
# 1  687fec04ac33c91790ef56acf1f00d53f2b91d1d.json
# 2  687fec04ac33c91790ef56acf1f00d53f2b91d1d.json
# 3  687fec04ac33c91790ef56acf1f00d53f2b91d1d.json
# 4  687fec04ac33c91790ef56acf1f00d53f2b91d1d.json
#
#                                                                                               title  \
# 0  Age-adjusted associations between comorbidity and outcomes of COVID-19: a review of the evidence
# 1  Age-adjusted associations between comorbidity and outcomes of COVID-19: a review of the evidence
# 2  Age-adjusted associations between comorbidity and outcomes of COVID-19: a review of the evidence
# 3  Age-adjusted associations between comorbidity and outcomes of COVID-19: a review of the evidence
# 4  Age-adjusted associations between comorbidity and outcomes of COVID-19: a review of the evidence
#
#                       section sectionNo sentid           token tokenStart  \
# 0  INCLUDE EXCLUDE Population         8      0  [Non-COVID-19]        [0]
# 1  INCLUDE EXCLUDE Population         8      0      [patients]       [13]
# 2  INCLUDE EXCLUDE Population         8      0             [(]       [22]
# 3  INCLUDE EXCLUDE Population         8      0           [e.g]       [23]
# 4  INCLUDE EXCLUDE Population         8      0             [.]       [26]
#
#     label  chunks  preexisting chunkStart
# 0  [None]  [None]            1     [None]
# 1  [None]  [None]            1     [None]
# 2  [None]  [None]            1     [None]
# 3  [None]  [None]            1     [None]
# 4  [None]  [None]            1     [None]

# %%
bigdf3=bigdf2.groupby(['docid','title','section','sectionNo','sentid'],as_index=False)['token','tokenStart','chunkStart','label','chunks'].sum()
# Out:
# /home/myilmaz/devel/mag/notebooks/3.7env/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
bigdf3.head(1)
# Out:
#                                            docid  \
# 0  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
#
#                                                                                                               title  \
# 0  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
#
#                          section sectionNo sentid  \
# 0  (which was not peer-reviewed)        70      0
#
#                                               token  \
# 0  [The, copyright, holder, for, this, preprint, .]
#
#                    tokenStart                                  chunkStart  \
# 0  [0, 4, 14, 21, 25, 30, 39]  [None, None, None, None, None, None, None]
#
#                                         label  \
# 0  [None, None, None, None, None, None, None]
#
#                                        chunks
# 0  [None, None, None, None, None, None, None]

# %%
bigdf3['label']=bigdf3['label'].apply(lambda x: [i for i in x if i])
bigdf3['chunks']=bigdf3['chunks'].apply(lambda x: [i for i in x if i])
bigdf3['chunkStart']=bigdf3['chunkStart'].apply(lambda x: [i for i in x if i])

# %%
bigdf3.drop(columns=['tokenStart'],inplace=True)

# %%
bigdf3['lenSent']=bigdf3['token'].apply(lambda x: len(' '.join(x)))

# %%
ready=bigdf3.merge(embed,on=['docid','section','sectionNo','sentid'],how='left')

# %%
ready.head(40)
# Out:
#                                             docid  \
# 0   01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 1   01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 2   01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 3   01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 4   01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 5   01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 6   01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 7   01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 8   01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 9   01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 10  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 11  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 12  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 13  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 14  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 15  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 16  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 17  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 18  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 19  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 20  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 21  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 22  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 23  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 24  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 25  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 26  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 27  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 28  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 29  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 30  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 31  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 32  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 33  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 34  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 35  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 36  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 37  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 38  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
# 39  01055f5d7f608ba085234b8e0d9b912bf304acd1.json
#
#                                                                                                                title  \
# 0   Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 1   Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 2   Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 3   Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 4   Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 5   Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 6   Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 7   Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 8   Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 9   Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 10  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 11  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 12  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 13  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 14  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 15  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 16  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 17  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 18  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 19  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 20  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 21  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 22  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 23  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 24  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 25  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 26  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 27  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 28  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 29  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 30  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 31  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 32  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 33  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 34  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 35  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 36  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 37  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 38  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
# 39  Association between ABO blood groups and clinical outcome of coronavirus disease 2019: Evidence from two cohorts
#
#                                                 section sectionNo sentid  \
# 0                         (which was not peer-reviewed)        70      0
# 1                         (which was not peer-reviewed)        70      1
# 2                         (which was not peer-reviewed)        70      2
# 3                         (which was not peer-reviewed)        70      3
# 4                         (which was not peer-reviewed)        71      0
# 5                         (which was not peer-reviewed)        74      0
# 6                         (which was not peer-reviewed)        77      0
# 7                      All baseline variables listed in        21      0
# 8                      All baseline variables listed in        21      1
# 9                      All baseline variables listed in        21      2
# 10                     All baseline variables listed in        21      3
# 11  Association between blood type and clinical outcome        33      0
# 12  Association between blood type and clinical outcome        33      1
# 13  Association between blood type and clinical outcome        34      0
# 14                CC-BY-NC-ND 4.0 International license        68      0
# 15                CC-BY-NC-ND 4.0 International license        69      0
# 16                CC-BY-NC-ND 4.0 International license        72      0
# 17                CC-BY-NC-ND 4.0 International license        73      0
# 18                CC-BY-NC-ND 4.0 International license        75      0
# 19                CC-BY-NC-ND 4.0 International license        76      0
# 20    Characteristics and outcomes of the study cohorts        22      0
# 21    Characteristics and outcomes of the study cohorts        22      1
# 22    Characteristics and outcomes of the study cohorts        22      2
# 23    Characteristics and outcomes of the study cohorts        22      3
# 24    Characteristics and outcomes of the study cohorts        23      0
# 25    Characteristics and outcomes of the study cohorts        24      0
# 26    Characteristics and outcomes of the study cohorts        24      1
# 27    Characteristics and outcomes of the study cohorts        25      0
# 28    Characteristics and outcomes of the study cohorts        25      1
# 29    Characteristics and outcomes of the study cohorts        26      0
# 30    Characteristics and outcomes of the study cohorts        27      0
# 31    Characteristics and outcomes of the study cohorts        27      1
# 32    Characteristics and outcomes of the study cohorts        27      2
# 33    Characteristics and outcomes of the study cohorts        27      3
# 34                                  Competing interests        60      0
# 35                                  Competing interests        61      0
# 36                                  Competing interests        61      1
# 37                                  Competing interests        62      0
# 38                                  Competing interests        62      1
# 39                                  Competing interests        62      2
#
#                                                                                                                                                                                                                                                                                                                                                token  \
# 0                                                                                                                                                                                                                                                                                                   [The, copyright, holder, for, this, preprint, .]
# 1                                                                                                                                                                                                            [Data, are, shown, as, n, (, %, ), for, categorical, variables, and, median, (, interquartile, range, ), for, continuous, variables, .]
# 2                                                                                                                                                                                                                                                                                               [ARDS, ,, Acute, respiratory, distress, syndrome, ;]
# 3                                                                                                                                                                                                                                                                                                                 [AKI, ,, Acute, kidney, injury, .]
# 4                                                                                                                                                                                                                                                                                                                                                [.]
# 5                                                                                                                                                                                                                                                                                                   [The, copyright, holder, for, this, preprint, .]
# 6                                                                                                                                                                                                                                                                                                      [The, copyright, holder, for, this, preprint]
# 7                                                                                                                                                                                                                    [For, statistical, presentation, ,, each, blood, group, was, compared, with, a, reference, group, (, blood, type, O, or, B, ).]
# 8                                                                            [A, stratified, analysis, of, a, reported, region, was, not, performed, given, that, there, were, no, substantial, differences, in, allele, distributions, and, divergent, genetic, background, in, participants, of, Han, nationality, between, different, regions, .]
# 9                                                                                                                                                                                                                                                        [Statistical, analyses, were, performed, using, SPSS, (, version, 22.0, ), for, Windows, .]
# 10                                                                                                                                                                                                                                                                                          [A, p-value, of, <0.05, was, considered, significant, .]
# 11                                                                                                                                                                                         [We, further, explored, the, relationship, between, blood, type, and, clinical, outcomes, of, critical, patients, with, severe, pneumonia, caused, by, .]
# 12                                                                                                                                                            [CC-BY-NC-ND, 4.0, International, license, It, is, made, available, under, a, author/funder, ,, who, has, granted, medRxiv, a, license, to, display, the, preprint, in, perpetuity, .]
# 13                                                                                                                                                                                                                                                   [is, the, (, which, was, not, peer-reviewed, ), The, copyright, holder, for, this, preprint, .]
# 36                                                                                                                                                            [CC-BY-NC-ND, 4.0, International, license, It, is, made, available, under, a, author/funder, ,, who, has, granted, medRxiv, a, license, to, display, the, preprint, in, perpetuity, .]
# 37                                                                                                                                                                                                                                                   [is, the, (, which, was, not, peer-reviewed, ), The, copyright, holder, for, this, preprint, .]
# 38                                                                                                                                                                                                                                                                                                              [https://doi.org/10.1101/2020.04, .]
# 39                                                                                                                                                                                                                                                                                                       [15.20063107, doi, :, medRxiv, preprint, .]
#
#               chunkStart                                      label  \
# 0                     []                                         []
# 1                     []                                         []
# 2             [150, 156]                     [B-PROBLEM, B-PROBLEM]
# 3             [193, 198]                     [B-PROBLEM, B-PROBLEM]
# 4                     []                                         []
# 5                     []                                         []
# 6                     []                                         []
# 7          [30, 84, 100]                   [B-TEST, B-TEST, B-TEST]
# 8        [104, 190, 242]             [B-TEST, B-PROBLEM, B-PROBLEM]
# 9                  [333]                                   [B-TEST]
# 10                 [408]                                   [B-TEST]
# 11             [45, 104]                     [B-PROBLEM, B-PROBLEM]
# 12                    []                                         []
# 13                    []                                         []
# 14                    []                                         []
# 15                    []                                         []
# 16                    []                                         []
# 17                    []                                         []
# 18                    []                                         []
# 19                    []                                         []
# 20              [52, 88]                     [B-PROBLEM, B-PROBLEM]
# 21  [231, 237, 246, 282]  [B-PROBLEM, B-PROBLEM, B-PROBLEM, B-TEST]
# 22                    []                                         []
# 23                    []                                         []
# 24                    []                                         []
# 25              [17, 74]                        [B-TEST, B-PROBLEM]
# 26                 [194]                                   [B-TEST]
# 27                    []                                         []
# 28                 [251]                                [B-PROBLEM]
# 29                  [16]                                [B-PROBLEM]
# 30              [45, 72]                     [B-PROBLEM, B-PROBLEM]
# 31             [81, 129]                     [B-PROBLEM, B-PROBLEM]
# 32            [166, 264]                        [B-PROBLEM, B-TEST]
# 33                 [314]                                [B-PROBLEM]
# 34                    []                                         []
# 35                    []                                         []
# 36                    []                                         []
# 37                    []                                         []
# 38                    []                                         []
# 39                    []                                         []
#
#                                                                                                     chunks  \
# 0                                                                                                       []
# 1                                                                                                       []
# 2                                                              [ARDS, Acute respiratory distress syndrome]
# 3                                                                               [AKI, Acute kidney injury]
# 4                                                                                                       []
# 5                                                                                                       []
# 6                                                                                                       []
# 7                                                                      [each blood group, blood type O, B]
# 8   [A stratified analysis, substantial differences in allele distributions, divergent genetic background]
# 9                                                                                   [Statistical analyses]
# 10                                                                                                     [A]
# 11                                                                          [blood type, severe pneumonia]
# 12                                                                                                      []
# 13                                                                                                      []
# 14                                                                                                      []
# 15                                                                                                      []
# 16                                                                                                      []
# 17                                                                                                      []
# 18                                                                                                      []
# 19                                                                                                      []
# 20                                                          [mild pneumonia, severe pneumonia in the mild]
# 21                                                               [ARDS, AKI, death, different blood types]
# 22                                                                                                      []
# 23                                                                                                      []
# 24                                                                                                      []
# 25                                                                [AB blood type, the insufficient number]
# 26                                                                                         [blood type AB]
# 27                                                                                                      []
# 28                                                                                        [aged sufferers]
# 29                                                                                       [the mild cohort]
# 30                                                                                [severe pneumonia, ARDS]
# 31                                                                [critically ill, multiple organ failure]
# 32                                                                                         [difference, B]
# 33                                                             [the difference between baseline variables]
# %%
ready.to_csv('riskready.csv',index=False)

# %% [markdown]
# ## Prep for visualizations

# %%
problems=bigdf2[bigdf2['label']=='B-PROBLEM']

# %%
tests=bigdf2[bigdf2['label']=='B-TEST']

# %%
#len(problems[problems['chunks']=='proteinuria'])

# %%
probhist=pd.DataFrame(problems['chunks'].value_counts())
probhist=probhist.rename(columns={'chunks':'counts'})
probhist2=probhist.iloc[0:100]

# %%
testhist=pd.DataFrame(tests['chunks'].value_counts())
testhist=testhist.rename(columns={'chunks':'counts'})
testhist2=testhist.iloc[0:100]

# %% [markdown]
# ## Look at most frequent "Test" entities

# %%
testhist2.head(40)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(figsize =(24,12))
chart=sns.barplot(testhist2.index,testhist2['counts'])
chart.set_xticklabels(testhist2.index,rotation=90)
plt.title('Test Entities',fontsize=18)
plt.show()

# %% [markdown]
# The pretrained model is returning a lot of false positive for Test entities, but you can still see that kidney related tests such as "creatinine" are well represented in the dataset.

# %% [markdown]
# ## Look at most frequent "Problem" entities

# %%
probhist2.iloc[39:79]

# %%
import seaborn as sns
import seaborn as sns
fig, ax = plt.subplots(figsize =(24,12))
chart=sns.barplot(probhist2.index,probhist2['counts'])
chart.set_xticklabels(probhist2.index,rotation=90)
plt.title('Problem Entities',fontsize=18)
plt.show()

# %% [markdown]
# You can see that kidney related problems such as "AKI" are well represented in the dataset.

# %% [markdown]
# ## Find 'Test' entities near the most frequent kidney related 'Problem' entity

# %%
problems=pd.DataFrame(problems).reset_index(drop=True)
problems['sectionid']=problems.docid+'-'+problems.section

# %%
tests=pd.DataFrame(tests).reset_index(drop=True)
tests['sectionid']=tests.docid+'-'+tests.section

# %%
akis=pd.DataFrame(problems[problems['chunks']=='AKI']).reset_index(drop=True)

# %%
a=list(set(akis['sectionid']))

# %%
akitest=tests[tests['sectionid'].isin(a)]

# %%
akicount=pd.DataFrame(akitest.groupby(['chunks'])['label'].count()).reset_index()

akicount=akicount.sort_values(by='label',ascending=False).reset_index(drop=True)
akicount.columns=['chunk','counts']

# %%
akicount

# %%
import seaborn as sns
import seaborn as sns
fig, ax = plt.subplots(figsize =(24,12))
chart= sns.barplot(akicount['chunk'][0:50],akicount['counts'][0:50])

chart.set_xticklabels(akicount.chunk,rotation=90)
plt.title("Clinical Tests Near 'AKI'",fontsize=20)


plt.show()

# %% [markdown]
# Our clinical tests NER is returning a lot of false positives but we still see that creatinine, CRP, and PCR tests  are well represented in the dataset, appearing in the same section as "AKI". This tells me the information is probably not historical and I will have measurements that I can use for predictions as well as terms to use for topic modelling and text classification.

# %% [markdown]
# ## Find 'Problem' entities near the most frequent kidney related 'Test' entity

# %%
creatins=pd.DataFrame(tests[tests['chunks']=='creatinine']).reset_index(drop=True)
b=list(set(creatins['sectionid']))
creatprob=problems[problems['sectionid'].isin(b)]
creatcount=pd.DataFrame(creatprob.groupby(['chunks'])['label'].count()).reset_index()

creatcount=creatcount.sort_values(by='label',ascending=False).reset_index(drop=True)
creatcount.columns=['chunk','counts']

# %%
creatcount

# %%
creatcounts=creatcount.iloc[0:50]

# %%
import seaborn as sns
import seaborn as sns
fig, ax = plt.subplots(figsize =(24,12))
chart= sns.barplot(creatcounts.chunk,creatcounts['counts'])

chart.set_xticklabels(creatcounts.chunk,rotation=90)
plt.title("Patient Problems Near 'Creatinine' Test",fontsize=20)


plt.show()

# %% [markdown]
# AKI, hypertension, diabetes, and acute kidney injury are all well represented in the dataset, appearing in the same section as "creatinine" tests. This tells me the information is probably not historical and I will have measurements that I can use for predictions as well as terms to use for topic modelling and text classification.

# %% [markdown]
# ## Frequency of 'patient' mentions in documents

# %%
patient=pd.DataFrame(big[(big['token'].str.lower()=='patient')|(big['token'].str.lower()=='patients')]).reset_index(drop=True)

# %%
patients=patient.groupby(['docid'])['token'].count()
patients=patients.reset_index()
patients=patients.rename(columns={'token':'counts'})
len(patients)

# %%
sns.boxplot(patients['counts'])
plt.title('Frequency of Patient Mentions in 1568 Documents',fontsize=14)

# %% [markdown]
# ## Frequency of 'case report' mentions in documents

# %%
case=pd.DataFrame(big[(big['section'].str.lower()=='case report')|(big['section']=='case study')|(big['chunks'].str.lower()=='case report')|(big['chunks'].str.lower()=='case study')|(big['section'].str.lower()=='case reports')|(big['section']=='case studies')|(big['chunks'].str.lower()=='case reports')|(big['chunks'].str.lower()=='case studies')]).reset_index(drop=True)

# %%
cases=case.groupby(['docid'])['section'].count()
cases=cases.reset_index()
cases=cases.rename(columns={'section':'counts'})
len(cases)

# %%
sns.boxplot(cases['counts'])
plt.title('Frequency of Case Report/Study Mentions in 78 Documents',fontsize=14)

# %% [markdown]
# 78 documents refer to case reports a median of about 550 times (The average document length is about 30,000 words.) I think I will have enough patient data to attempt some predictions.

# %%
artlist=kag['Study']
pres=[]
doc=[]
for i in os.listdir('document_parses/pdf_json'):
    with open('document_parses/pdf_json/'+i) as json_file:
        data = json.load(json_file)
        if data['metadata']['title'] in list(artlist):
            for c,j in enumerate(data['body_text']):
            
          
                row=[i,data['metadata']['title'],data['body_text'][c]['section'],data['body_text'][c]['text']]
                doc.append(row)

            pres.append(doc)

# %%
jsons=[j[0] for i in pres for j in i]
titles=[j[1] for i in pres for j in i]
sections=[j[2].lower() for i in pres for j in i]
text=[j[1].lower()+'.  '+j[2].lower()+'.  '+j[3].lower() for i in pres for j in i]
pres2=pd.DataFrame(None,columns=['jsons','titles','sections','text'])

# %%
pres2['jsons']=jsons
pres2['titles']=titles
pres2['section']=sections
pres2['text']=text

# %%
pres2.head(1)

# %%
case=pd.DataFrame(pres2[(pd.Series(pres2['section']).str.contains('case report'))|(pd.Series(pres2['section']).str.contains('case study'))|(pd.Series(pres2['text']).str.contains('case report'))|(pd.Series(pres2['text']).str.contains('case study'))|(pd.Series(pres2['section']).str.contains('case reports'))|(pd.Series(pres2['section']).str.contains('case studies'))|(pd.Series(pres2['text']).str.contains('case reports'))|(pd.Series(pres2['text']).str.contains('case studies'))]).reset_index(drop=True)

# %%
case.head()

# %%
len(case)

# %%
case['jsons'].nunique()

# %%
case['titles'].value_counts()
